# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('utubeSongsVidsDetails.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                          Vid-Title
# 0           0  J Balvin & Ed Sheeran - Forever My Love [Offic...  \
# 1           1     J Balvin & Ed Sheeran - Sigue [Official Video]
# 2           2         J Balvin, Ed Sheeran - Sigue (Lyric Video)
# 3           3  J Balvin, Ed Sheeran - Forever My Love (Lyric ...
# 4           4  J Balvin, Willy William - Mi Gente (Official V...
#
#   Playlist-Name channel-Title       Views        Published-date       Likes
# 0      J Balvin    Ed Sheeran    18166683  2022-03-25T00:00:12Z    450989.0  \
# 1      J Balvin   jbalvinVEVO    27973997  2022-03-25T00:00:08Z    459247.0
# 2      J Balvin   jbalvinVEVO      527009  2022-05-31T16:00:02Z     13113.0
# 3      J Balvin   jbalvinVEVO      588735  2022-05-31T16:00:25Z     15738.0
# 4      J Balvin   jbalvinVEVO  3236210587  2017-06-30T04:00:05Z  17722967.0
#
#    Comment-count       Vid-ID
# 0        14381.0  bqtMJ391poA
# 1        18223.0  8pIzxS_G8-g
# ...

# %%
df.shape
# Out:
# (870, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      870 non-null    int64
#  1   Vid-Title       870 non-null    object
#  2   Playlist-Name   870 non-null    object
#  3   channel-Title   870 non-null    object
#  4   Views           870 non-null    int64
#  5   Published-date  870 non-null    object
#  6   Likes           869 non-null    float64
#  7   Comment-count   867 non-null    float64
#  8   Vid-ID          870 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 61.3+ KB

# %% [markdown]
# #### Removing unnecessary columns

# %%
to_drop = df.columns[0]
df = df.drop(to_drop, axis=1)

# %% [markdown]
# #### Duplicated Values

# %%
df.nunique()
# Out:
# Vid-Title         660
# Playlist-Name       6
# channel-Title     124
# Views             671
# Published-date    606
# Likes             668
# Comment-count     630
# Vid-ID            661
# dtype: int64

# %%
df[df.duplicated('Vid-ID')]
# Out:
#                                              Vid-Title         Playlist-Name
# 19   J Balvin - Safari ft. Pharrell Williams, BIA, ...              J Balvin  \
# 21               J. Balvin - Ay Vamos (Official Video)              J Balvin
# 24   J Balvin, Willy William - Mi Gente (Official V...              J Balvin
# 27                         J Balvin - 6 AM ft. Farruko              J Balvin
# 54   J Balvin & Ed Sheeran - Forever My Love [Offic...              J Balvin
# ..                                                 ...                   ...
# 807  Something Different - Why Don't We [Official M...          Why Don't We
# 841     DPR LIVE, DPR CREAM - Gravity (Official Audio)  Dream Perfect Regime
# 860  DPR LIVE, DPR IAN, peace. - Diamonds + and Pea...  Dream Perfect Regime
# 861            DPR LIVE - Summer Tights (OFFICIAL M/V)  Dream Perfect Regime
# 866  DPR IAN - No Blueberries (ft. DPR LIVE, CL) OF...  Dream Perfect Regime
#
# ...

# %% [markdown]
# #### Removing dupicated values

# %%
df = df.drop_duplicates('Vid-ID',keep='last')

# %%
df
# Out:
#                                              Vid-Title         Playlist-Name
# 2           J Balvin, Ed Sheeran - Sigue (Lyric Video)              J Balvin  \
# 3    J Balvin, Ed Sheeran - Forever My Love (Lyric ...              J Balvin
# 11   Chris Jedi - Ahora Dice (Official Video) ft. J...              J Balvin
# 13   Zion & Lennox ft. J Balvin - Otra Vez (Video O...              J Balvin
# 17   David Guetta, Bebe Rexha & J Balvin - Say My N...              J Balvin
# ..                                                 ...                   ...
# 865  "Memories In Disorder" | OFFICIAL 'MITO' DOCUM...  Dream Perfect Regime
# 866  DPR IAN - No Blueberries (ft. DPR LIVE, CL) OF...  Dream Perfect Regime
# 867              DPR IAN - So Beautiful (OFFICIAL M/V)  Dream Perfect Regime
# 868                                    Adobe x DPR IAN  Dream Perfect Regime
# 869                 our last dream - take 1 (Mongolia)  Dream Perfect Regime
#
# ...

# %%
df.reset_index()
# Out:
#      index                                          Vid-Title
# 0        2         J Balvin, Ed Sheeran - Sigue (Lyric Video)  \
# 1        3  J Balvin, Ed Sheeran - Forever My Love (Lyric ...
# 2       11  Chris Jedi - Ahora Dice (Official Video) ft. J...
# 3       13  Zion & Lennox ft. J Balvin - Otra Vez (Video O...
# 4       17  David Guetta, Bebe Rexha & J Balvin - Say My N...
# ..     ...                                                ...
# 656    865  "Memories In Disorder" | OFFICIAL 'MITO' DOCUM...
# 657    866  DPR IAN - No Blueberries (ft. DPR LIVE, CL) OF...
# 658    867              DPR IAN - So Beautiful (OFFICIAL M/V)
# 659    868                                    Adobe x DPR IAN
# 660    869                 our last dream - take 1 (Mongolia)
#
#             Playlist-Name         channel-Title       Views
# 0                J Balvin           jbalvinVEVO      527009  \
# 1                J Balvin           jbalvinVEVO      588735
# ...

# %%
df = df.reset_index()

# %% [markdown]
# #### NULL Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 661 entries, 0 to 660
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           661 non-null    int64
#  1   Vid-Title       661 non-null    object
#  2   Playlist-Name   661 non-null    object
#  3   channel-Title   661 non-null    object
#  4   Views           661 non-null    int64
#  5   Published-date  661 non-null    object
#  6   Likes           660 non-null    float64
#  7   Comment-count   658 non-null    float64
#  8   Vid-ID          661 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 46.6+ KB

# %%
df.isnull().sum()
# Out:
# index             0
# Vid-Title         0
# Playlist-Name     0
# channel-Title     0
# Views             0
# Published-date    0
# Likes             1
# Comment-count     3
# Vid-ID            0
# dtype: int64

# %%
df1 = df[df.isna().any(axis=1)]

# %%
df1
# Out:
#      index                                          Vid-Title
# 327    486  Selena Gomez: My Mind & Me — An Exclusive Conv...  \
# 557    762  'Why Don't We' Talks Hair Styling Rituals and ...
# 559    764  Why Don't We Plays This Or That (Things Get Cr...
# 574    779                              Why Dont We Interview
#
#             Playlist-Name     channel-Title    Views        Published-date
# 327          Music Videos          Apple TV  2809571  2022-11-06T03:29:46Z  \
# 557  Why Don't We • Vlogs          WiLD 949   632800  2017-08-10T19:03:19Z
# 559  Why Don't We • Vlogs  Teenage Magazine   791243  2019-01-28T02:35:06Z
# 574  Why Don't We • Vlogs         HITS 97.3   117542  2018-04-05T14:31:20Z
#
#        Likes  Comment-count       Vid-ID
# 327  71448.0            NaN  Lz5MM6ysmeI
# 557      NaN         1056.0  4VPvi_Lg4MU
# 559  35971.0            NaN  JV_GcyBXuk8
# 574   4591.0            NaN  JB8ygV3JPGE

# %%
# to_fill = df.loc[762, :]
# df = df.bfill(axis ='rows')
# df[df.isna().any(axis=1)]

# %%
df.head()
# Out:
#    index                                          Vid-Title Playlist-Name
# 0      2         J Balvin, Ed Sheeran - Sigue (Lyric Video)     Favorites  \
# 1      3  J Balvin, Ed Sheeran - Forever My Love (Lyric ...     Favorites
# 2     11  Chris Jedi - Ahora Dice (Official Video) ft. J...     Favorites
# 3     13  Zion & Lennox ft. J Balvin - Otra Vez (Video O...     Favorites
# 4     17  David Guetta, Bebe Rexha & J Balvin - Say My N...     Favorites
#
#    channel-Title       Views        Published-date      Likes  Comment-count
# 0    jbalvinVEVO      526876  2022-05-31T16:00:02Z    13112.0          270.0  \
# 1    jbalvinVEVO      588625  2022-05-31T16:00:25Z    15737.0          449.0
# 2  ChrisJediVEVO  1375118431  2017-03-20T04:00:01Z  4904465.0       156723.0
# 3  Zion & Lennox  1230064961  2016-08-05T15:00:01Z  2936249.0        77090.0
# 4   David Guetta   992035551  2018-11-20T19:00:06Z  5766324.0        90681.0
#
#         Vid-ID
# 0  3dCARL28qKs
# 1  nKYFMqmV_Hg
# ...

# %%
df.groupby('Playlist-Name')[['Likes']].sum()
# Out:
#                                                 Likes
# Playlist-Name
# Concept Videos                              6663499.0
# Doja Cat - Video Essentials                56176920.0
# Favorites                                 192667911.0
# Music Videos                              130666602.0
# The Weeknd - House Of Balloons (Mixtape)   84078432.0
# Why Don't We • Vlogs                       18223780.0

# %%
df.groupby('channel-Title')[['Likes']].sum()
# Out:
#                      Likes
# channel-Title
# All Def Music     250651.0
# Anitta           4572465.0
# Anuel AA         8552853.0
# Apple TV           71448.0
# AskAnythingChat    41776.0
# ...                    ...
# karoliina          17115.0
# kdwb1013           24307.0
# reikVEVO          835151.0
# theotherlinda       1236.0
# 𝙏𝙀𝙀𝙉𝙈𝘼𝙂            24320.0
#
# [124 rows x 1 columns]

# %%
df[["Likes", "Comment-count"]] = df[["Likes", "Comment-count"]].apply(pd.to_numeric,downcast='integer')

# %%
x = df[["Likes", "Comment-count"]].apply(pd.to_numeric,downcast='integer')
